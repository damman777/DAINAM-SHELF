# %% [markdown]
# <a href="https://colab.research.google.com/github/damman777/DAINAM-SHELF/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name = "Damman"
last_name = "Azeemi"
print(first_name , last_name)
# Out:
# Damman Azeemi

# %%
fav_caleberity = "KSA"
paragrapgh = """Hi my favourite celeberity is
Azeemi
Love"""
print(paragrapgh , fav_caleberity)
# Out:
# Hi my favourite celeberity is
# Azeemi
# Love KSA

# %%
fav_cele = "KSA"
print(f"My name is {fav_cele}")
# Out:
# My name is KSA

# %%
a = 20
b=30
result = ""
print("result" , a+b)
# Out:
# result 50

# %%
c = 40
d = 20
sub = ""
print("Sub" , c-d)
# Out:
# Sub 20

# %%
e = 8
f = 40
division = ""
print("Division" , e / f)
# Out:
# Division 0.2

# %%
g = 8
h = 40
division = ""
print("Modulus" , g % h)
# Out:
# Modulus 8

# %%
i = 8
division = ""
print("Exponent" , i ** 5)
# Out:
# Exponent 32768

# %%
name = "Damman"
city = "Karachi"
age = 21
print(f"My name is {name} I live in {city} and my age is {age}")
# Out:
# My name is Damman I live in Karachi and my age is 21

# %%
obj = "clock"
num = 21
decimal = 0.2
print(type(obj))
print(type(num))
print(type(decimal))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
math = 80
eng = 90
sci = 88
Total_Marks = ""
print("Total Marks" , math + eng + sci)
# Out:
# Total Marks 258

# %%
year = 2025
print(f"Cureent Year is {year}")
# Out:
# Cureent Year is 2025

# %%
a = 10
b = 20
print(f"""The sum of {a} and {b} is 13
          The product of {a} and {b} is 30""")
# Out:
# The sum of 10 and 20 is 13
#           The product of 10 and 20 is 30

# %%
faculty = 12
admin = 4
students = 100
absent = 15
per_person_rabri = 250
total_members = faculty + admin + students
total_pre_members = total_members - absent
print(f"Total Present Members: {total_pre_members}")
print(f"Total Rabri In Grams: {total_pre_members * per_person_rabri}")
total_rabri_kg = total_pre_members * per_person_rabri
print(f"Total Rabri In Kg: {total_rabri_kg // 1000}")
# Out:
# Total Present Members: 101
# Total Rabri In Grams: 25250
# Total Rabri In Kg: 25
